# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('D:\Datasets\day.csv')

# %%
df
# Out:
#      instant    dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  01/01/11       1   0     1        0        6           0
# 1          2  02/01/11       1   0     1        0        0           0
# 2          3  03/01/11       1   0     1        0        1           1
# 3          4  04/01/11       1   0     1        0        2           1
# 4          5  05/01/11       1   0     1        0        3           1
# ..       ...       ...     ...  ..   ...      ...      ...         ...
# 726      727  27/12/12       1   1    12        0        4           1
# 727      728  28/12/12       1   1    12        0        5           1
# 728      729  29/12/12       1   1    12        0        6           0
# 729      730  30/12/12       1   1    12        0        0           0
# 730      731  31/12/12       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
df.shape
# Out:
# (731, 16)

# %%
df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.cnt.describe()
# Out:
# count     731.000000
# mean     4504.348837
# std      1937.211452
# min        22.000000
# 25%      3152.000000
# 50%      4548.000000
# 75%      5956.000000
# max      8714.000000
# Name: cnt, dtype: float64

# %%
df.windspeed.describe()
# Out:
# count    731.000000
# mean       0.190486
# std        0.077498
# min        0.022392
# 25%        0.134950
# 50%        0.180975
# 75%        0.233214
# max        0.507463
# Name: windspeed, dtype: float64

# %%
df[['cnt','windspeed']].describe()
# Out:
#                cnt   windspeed
# count   731.000000  731.000000
# mean   4504.348837    0.190486
# std    1937.211452    0.077498
# min      22.000000    0.022392
# 25%    3152.000000    0.134950
# 50%    4548.000000    0.180975
# 75%    5956.000000    0.233214
# max    8714.000000    0.507463

# %%
print("Skewness is:",df.cnt.skew())
print("Kurtosis is:",df.cnt.kurt())
# Out:
# Skewness is: -0.04735278011900183
# Kurtosis is: -0.8119223847191548

# %%
print("Skewness is:",df.windspeed.skew())
print("Kurtosis is:",df.windspeed.kurt())
# Out:
# Skewness is: 0.6773454211095378
# Kurtosis is: 0.4109222677315354

# %%
df[['cnt','windspeed']].skew()
# Out:
# cnt         -0.047353
# windspeed    0.677345
# dtype: float64

# %%
df[['cnt','windspeed']].kurt()
# Out:
# cnt         -0.811922
# windspeed    0.410922
# dtype: float64

# %%
df.season.value_counts().nlargest()
# Out:
# 3    188
# 2    184
# 1    181
# 4    178
# Name: season, dtype: int64

# %%
df.weathersit.value_counts()
# Out:
# 1    463
# 2    247
# 3     21
# Name: weathersit, dtype: int64

# %%
df[['season','weathersit']].value_counts()
# Out:
# season  weathersit
# 3       1             136
# 2       1             113
# 1       1             111
# 4       1             103
# 2       2              68
# 1       2              66
# 4       2              65
# 3       2              48
# 4       3              10
# 1       3               4
# 3       3               4
# 2       3               3
# dtype: int64

# %%
df[['season','weathersit']].head()
# Out:
#    season  weathersit
# 0       1           2
# 1       1           2
# 2       1           1
# 3       1           1
# 4       1           1

# %%
df.cnt.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.cnt.plot(kind='box',vert=False)
# Out:
# <Axes: >

# %%
df.cnt.plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df.windspeed.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.windspeed.plot(kind='box',vert=False)
# Out:
# <Axes: >

# %%
df.windspeed.plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
# Non numeric 

df.season.value_counts()
# Out:
# 3    188
# 2    184
# 1    181
# 4    178
# Name: season, dtype: int64

# %%
df.weathersit.value_counts()
# Out:
# 1    463
# 2    247
# 3     21
# Name: weathersit, dtype: int64

# %%
# corss tabulation: Frequency Count of 2 or more Non Numeric categorical variables.
# variables. pd.crosstab()
# Season wise Weathersit
# for cross tabluation we used stacked bar plots

pd.crosstab(df.season,df.weathersit)
# Out:
# weathersit    1   2   3
# season
# 1           111  66   4
# 2           113  68   3
# 3           136  48   4
# 4           103  65  10

# %%
ax =  pd.crosstab(df.weathersit,df.season).plot(kind='bar',stacked=True)
for i in ax.containers:
    ax.bar_label(i)

# %%
# How many weekdays are holidays
df[['weekday','holiday']]
# Out:
#      weekday  holiday
# 0          6        0
# 1          0        0
# 2          1        0
# 3          2        0
# 4          3        0
# ..       ...      ...
# 726        4        0
# 727        5        0
# 728        6        0
# 729        0        0
# 730        1        0
#
# [731 rows x 2 columns]

# %%
pd.crosstab(df.holiday,df.weekday)
# Out:
# weekday    0   1    2    3    4    5    6
# holiday
# 0        105  90  103  103  102  102  105
# 1          0  15    1    1    2    2    0

# %%
# Data aggregation
# what is the average cnt for holiday 0/1?


# df.number_of_reviews.groupby(df.neighbourhood).sum().sort_values(ascending = False).nlargest(10)

df.cnt.groupby(df.holiday).mean()
# Out:
# holiday
# 0    4527.104225
# 1    3735.000000
# Name: cnt, dtype: float64

# %%
# Median windspeed for different weatersit

df.head()
# Out:
#    instant    dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01/01/11       1   0     1        0        6           0
# 1        2  02/01/11       1   0     1        0        0           0
# 2        3  03/01/11       1   0     1        0        1           1
# 3        4  04/01/11       1   0     1        0        2           1
# 4        5  05/01/11       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
df.windspeed.groupby(df.weathersit).median()
# Out:
# weathersit
# 1    0.178496
# 2    0.179725
# 3    0.248150
# Name: windspeed, dtype: float64

# %%
# what is the avg temp of different season
 
df.temp.groupby(df.season).mean()
# Out:
# season
# 1    0.297748
# 2    0.544405
# 3    0.706309
# 4    0.422906
# Name: temp, dtype: float64

# %%
# what is the median humidity for differnet season
df.hum.groupby(df.season).median()
# Out:
# season
# 1    0.544167
# 2    0.644375
# 3    0.635000
# 4    0.661042
# Name: hum, dtype: float64

# %%
ax = df.hum.groupby(df.season).median().sort_values(ascending=False).plot(kind='bar',color='green')

for i in ax.containers:
    ax.bar_label(i,color='brown')

# %%
sns.distplot(df.cnt)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_10244\1509912878.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.cnt)
# <Axes: xlabel='cnt', ylabel='Density'>

# %%
sns.boxplot(df.cnt,orient='h')
# Out:
# <Axes: >

# %%
df.cnt.plot(kind='box',vert=False)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(30,15))

fig,ax = plt.subplots(1,3)
sns.kdeplot(df.cnt,ax=ax[0])
sns.boxplot(df.cnt,ax=ax[1],orient='h')
sns.histplot(df.cnt,ax=ax[2])
plt.show()

# %%
# Descriptive Statistics - Bivariate Statistics - 2 variable Statistics:
# The Measures of realationship- Covariance and Correlation
# Covariance points to directionality of movement of 2 variables
# Posistive Covariance - Both Variables moving in same direction
# Negative Covariance - Bot Variables moving in Opposite direction

# Correlation quantifies the relationship between 2 variables in numeric terms.
# Correlations lies between -1 to 1.

# Covariance and correlation measure the relationship and the dependency between two variables. 
# Covariance indicates the direction of the linear relationship between variables while correlation measures 
# both the strength and direction of the linear relationship between two variables. Correlation is a function of the covariance.

# Bivarient plot - Scatter plot

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
numvars = df[['temp', 'atemp', 'hum', 'windspeed','casual', 'registered', 'cnt']]

# %%
numvars.cov() # Covariance
# Out:
#                   temp       atemp        hum  windspeed         casual  \
# temp          0.033508    0.029583   0.003310  -0.002241      68.283781
# atemp         0.029583    0.026556   0.003249  -0.002319      60.854436
# hum           0.003310    0.003249   0.020286  -0.002743      -7.530987
# windspeed    -0.002241   -0.002319  -0.002743   0.006006      -8.919005
# casual       68.283781   60.854436  -7.530987  -8.919005  471450.441418
# registered  154.230919  138.366859 -20.242247 -26.293180  423468.902417
# cnt         222.514700  199.221295 -27.773235 -35.212185  894919.343836
#
#               registered           cnt
# temp        1.542309e+02  2.225147e+02
# atemp       1.383669e+02  1.992213e+02
# hum        -2.024225e+01 -2.777323e+01
# windspeed  -2.629318e+01 -3.521218e+01
# casual      4.234689e+05  8.949193e+05
# registered  2.434400e+06  2.857869e+06
# cnt         2.857869e+06  3.752788e+06

# %%
numvars.corr() # Correlation
# Out:
#                 temp     atemp       hum  windspeed    casual  registered  \
# temp        1.000000  0.991702  0.126963  -0.157944  0.543285    0.540012
# atemp       0.991702  1.000000  0.139988  -0.183643  0.543864    0.544192
# hum         0.126963  0.139988  1.000000  -0.248489 -0.077008   -0.091089
# windspeed  -0.157944 -0.183643 -0.248489   1.000000 -0.167613   -0.217449
# casual      0.543285  0.543864 -0.077008  -0.167613  1.000000    0.395282
# registered  0.540012  0.544192 -0.091089  -0.217449  0.395282    1.000000
# cnt         0.627494  0.631066 -0.100659  -0.234545  0.672804    0.945517
#
#                  cnt
# temp        0.627494
# atemp       0.631066
# hum        -0.100659
# windspeed  -0.234545
# casual      0.672804
# registered  0.945517
# cnt         1.000000

# %%
sns.heatmap(numvars.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(numvars)
