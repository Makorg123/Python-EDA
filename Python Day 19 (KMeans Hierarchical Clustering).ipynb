# %%
# Unsupervised Learning - Clustering Techniques - Hierarchical Clustering

# Hierarchical Clustering which groups data into hierarchy of clusters in the form of a tree called dendogram.

# Distance metrics are similar to KMeans and default is Euclidean.

# Within hierarchy clustering - Linkage is how it calculates the distance between 2 clusters

# Two Approaches in Hierarchical Clustering

# 1) Agglomerative - Bottom Up Approach which starts by taking all data points as a single cluster and merging them till 
# one cluster is left

# 2) Dvisive - Top Down Approach which starts by taking all data points as a single cluster and merges till one cluster is left.

# %% [markdown]
# ![image.png](attachment:image.png)
