# %%
# Supervised Learning - Classification Only Model - Naive Bayes Algorithm
# Naive Bayes is based on probablilty and uses conditional probablity as basis. 
# In Conditional probability, Bayes Theoram is important.
# Conditional Probability Formula.

#           p(A∩B)                 p(A∩B)
# p(A|B) = -------    or p(B|A) = -----------
#           p(B)                    p(A)


# Examples.
# 1) Probability of a student passing a science exam is 4/5 and that of student passing in botb science and maths is 1/2.
# What is the probability of that student passing in maths knowing he passed in science exam?

# Assume A - passing in science and  B - passing in maths
# p(A) = 4/5
# p(A∩B) = 1/2

# p(B|A) = p(A∩B)/p(A) = 1/2 / 4/5 = 0.5/0.8 = 0.625 or 62.5%



# 2)A servey found 60% read hindi newspaper, 40% read english newspaper and 20% read both. If a person is choosedn at random and  
# if he already reads english paper, find the probability he also reads hindi paper?

# Assume p(A) = 0.60(60%), p(B) = 0.40(40%), p(A∩B) = 0.20(20%)


# p(A|B) = p(A∩B)/p(B) = 0.20/0.40 = 0.5 or 50%

# %%
# bayes Theoraem and Conditional probability - Likelihood of an outocome occuring based on a previous outcome having occured 
# in similar circumstances.
# Bayes theorem provides a way to revise existing predictions(update probabilites) given new or additional evidence.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 3 persons, A, B, C have applied for a job in a company and chance of seletion are in ration of 1:2:4 sequenctially.
# Probabilities that A, B, and C can introduce changes in management in the company to improve profits are 0.8, 0.5 and 0.3 
# respectively. If the change does not take place find the probabiliy that it is due to appointment of C.


# First define events
# E1 - A gets Selected; E2 - B Gets Selected; E3 - C gets Selected

# Assume A -  Changes introduced but profit not happened.

# p(E1) =  1/7 , p(E2) = 2/7, p(E3) = 4/7

# p(A|E1) = p(Profit not appened by Changes done by A) = 1-p(profit happened by Changes done by A) = 1-0.80 = 0.20

# p(A|E2) = p(Profit not appened by Changes done by B) = 1-p(profit happened by Changes done by B) = 1-0.50 = 0.50

# p(A|E3) = p(Profit not appened by Changes done by C) = 1-p(profit happened by Changes done by C) = 1-0.30 = 0.70


# Find the probability of profit not happening due to selection of C

#                                p(A|E3) * p(E3)
# p(E3|A) = ---------------------------------------------------------
#              p(A|E1)*p(E1) + p(A|E2)*p(E2) + p(A|E3)*p(E3)


#                                0.70 * 4/7
# p(E3|A) = ---------------------------------------------------------
#              0.20 * 1/7 + 0.50 * 2/7 + 0.70 * 4/7


#                                0.40             0.40
# p(E3|A) = --------------------------------- = ------- =  0.702
#                        0.029 + 0.14 + 0.40     0.569


# Find the probability of profit not happening due to selection of A


#                                p(A|E1) * p(E1)
# p(E1|A) = ---------------------------------------------------------
#              p(A|E1)*p(E1) + p(A|E2)*p(E2) + p(A|E3)*p(E3)


#                                0.20 * 1/7
# p(E1|A) = ---------------------------------------------------------
#              0.20 * 1/7 + 0.50 * 2/7 + 0.70 * 4/7


#                               0.029            0.029
# p(E1|A) = --------------------------------- = ------- =  0.050
#                        0.029 + 0.14 + 0.40     0.569

# %%
# Bayes Rule in ML - X is independent variable and y is dependent variable

#           p(X|y) * p(y)
# p(y|X) = ---------------
#                p(X)


# p(y|X) =  Probability of y occuring given evidence X has occured
# p(X|y) =  Probability of X occuring given evidence y has occured
# p(X) & p(y) = Probability of events y & X occuring

# Naive Bayes forula for multiple independent Variables(X's) and multiple levels/classes in dependent variable

#                            p(X1|y=k) * p(X2|y=k) * pp(X3|y=k)......*p(Xn|y=k)*p(y=k)
# p(y=k|X2,X2,X3,....Xn) = -----------------------------------------------------------
#                                 p(X1) * p(X2) * p(X3).................* p(Xn)


# y - dependent variable
# X - levels or classes in dependent variables
# X1,X2, X3,...Xn - Independent variables

# %%
# Naive Bayes fast and predicts for both binary and multinomial data. 
# Performs well with less amount of training data.
# Performs well when there are more number of categorical varibales as independent variables

# Types of NB are:
# BernouliNB    - if majority of independent variables are binary.
# MultinomialNB - if dependent variables has more than 2 levles.
# GaussianNB    - if majority of independent variables are numerical.
